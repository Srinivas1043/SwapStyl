# %%
# Plan for localization update
keys_to_add = [
    # Home Screen / Feed
    "noItemsYet", "noItemsDesc", "refresh", 
    "filtersTitle", "reset", "applyFilters",
    "sortBy", "category", "gender", "size", "condition", "searchRadius",
    "color", "brand",
    "about", "unknown",
    "matchTitle", "matchMessage", "keepSwiping"
    
    # Options (can align with existing arrays or just translate headers)
    # SORT_OPTIONS etc map to keys? Maybe overkill for now, just main UI text.
]
